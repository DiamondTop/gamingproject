# %%
import requests
from pprint import pprint
import pandas as pd
import re
import numpy as np

# %%
#test
base_url = "https://api-v3.igdb.com/"
header={"user-key":"12e42347a0a2ee0b7a738578e40fe301 "}
end_point='games'
params={"fields":"aggregated_rating,name,videos,game_modes,genres", "filter[aggregated_rating][gt]":"0", "limit":"100",}
# filter[platform][eq]=48

# %%
#primary ds
base_url = "https://api-v3.igdb.com/games"
header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
params={"fields": "age_ratings,aggregated_rating,aggregated_rating_count,category,dlcs,expansions,first_release_date,follows,franchise,franchises,game_modes,hypes,keywords, multiplayer_modes,name,popularity,pulse_count,rating,rating_count,release_dates, similar_games,slug,storyline,summary,tags,themes,time_to_beat,total_rating,total_rating_count,artworks,url,genres", "order":"popularity:desc", "limit" :"500"}

# %%
# game modes
base_url = "https://api-v3.igdb.com/game_modes"
header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
params={"fields":"name,slug, url ", "limit" : 500 }

# %%
#genres
base_url = "https://api-v3.igdb.com/genres"
header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
params={"fields":"slug, url ", "limit" : 500 }

# %%
#themes
base_url = "https://api-v3.igdb.com/themes"
header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
params={"fields":"slug, url ", "limit" : 500 }

# %%
#Age Rating Descriptions
base_url = "https://api-v3.igdb.com/age_rating_content_descriptions"
header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
params={"fields":"*", "limit" : 500 }

# %%
#Age Ratings
ids = []
ratings = []
for item in rates:
    base_url = "https://api-v3.igdb.com/age_ratings"
    header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
    params={"fields":"*", "limit" : 500, "filter[id][eq]": item }
    response = requests.get(base_url,headers=header,params=params)
    print(response)
    df = pd.DataFrame(response.json())
    ids.append(df['id'][0])
    ratings.append(df['rating'][0])
    
#/release_dates/?fields=*&filter[platform][eq]=48&order=date:asc&filter[date][gt]=1500619813000&expand=game
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
#Achievements
category = []
game = []
language = []
owners_percentage = []
slug = []
for id in ids:
    base_url = "https://api-v3.igdb.com/achievements"
    header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
    params={"fields":"*", "limit" : 500, "filter[game][eq]": id }
    response = requests.get(base_url,headers=header,params=params)
    print(response)
    df = pd.DataFrame(response.json())
    try: category.append(df['category'][0])
    except: 
        print('no category found!')
        category.append(0)
    try: game.append(df['game'][0])
    except: 
        print('no game found')
        game.append(0)
    try: language.append(df['language'][0])
    except: 
        print("no language found!")
        language.append(0)
    try: owners_percentage.append(df['owners_percentage'][0])
    except: 
        print("no owners_percentage found!")
        owners_percentage.append(0)
    try: slug.append(df['slug'][0])
    except: 
        print("no slug found!")
        slug.append(0)
# Out:
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# <Response [200]>
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# <Response [200]>
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!
# <Response [200]>
# no language found!
# <Response [200]>
# no language found!
# no owners_percentage found!
# <Response [200]>
# no category found!
# no game found
# no language found!
# no owners_percentage found!
# no slug found!

# %%
#Artworks
game_ids = []
art_urls = []
for item in ids:
    base_url = "https://api-v3.igdb.com/artworks"
    header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
    params={"fields":"*", "limit" : 500, "filter[game][eq]": item }
    response = requests.get(base_url,headers=header,params=params)
    print(response)
    try:
        df2 = pd.DataFrame(response.json())
    except:
        print("UNABLE TO JSON")
    try:
        game_ids.append(df2.loc[:,'game'])
    except:
        print("NO GAME ID")
    try:
        art_urls.append(df2.loc[:,'url'])
    except: 
        print("NO URL")
# Out:
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# NO GAME URL
# NO URL
# <Response [200]>
# <Response [200]>
# <Response [200]>
# NO GAME URL
# NO URL

# %%
#Franchise
slugs = []
f_urls = []
f_ids = []
for item in franchise:
    if item != 0:
        base_url = "https://api-v3.igdb.com/franchises"
        header={"user-key":"12e42347a0a2ee0b7a738578e40fe301"}
        params={"fields":"*", "limit" : 500, "filter[id][eq]": item }
        response = requests.get(base_url,headers=header,params=params)
        print(response)
        try:
            df2 = pd.DataFrame(response.json())
        except:
            print("UNABLE TO JSON")
        try:
            slugs.append(df2.loc[:,'slug'])
        except:
            print("NO SLUG")
        try:
            f_urls.append(df2.loc[:,'url'])
        except: 
            print("NO URL")
        try:
            f_ids.append(df2.loc[:,'id'])
        except: 
            print("NO URL")
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
dlcs = df_p.loc[:,'dlcs']
expansions = df_p.loc[:,'expansions']
release_dates = df_p.loc[:,'release_dates']

# %%
#Similar Games

similar_game = []
ids2 = []

for c, i in enumerate( similar_games ):
    i = i.replace('[', "")
    i = i.replace(' ', "")
    i = i.replace('0', "")
    i = i.replace('\'', "")
    i = i.replace(']', "").split(",")
    similar_game.append(i)
    ids2.append(ids[c])
    
similar_game2 = []
ids3 = []

for c, thing in enumerate( similar_game ):
    for item in thing:
        similar_game2.append(item)
        ids3.append(ids[c])
        
df = pd.DataFrame(list(zip(similar_game2, ids3)), 
               columns =['game_id', 'url']) 
df.to_csv('similar_games_ds.csv')

# %%
df = pd.read_csv('original_ds.csv')

# %%
age_ratings = df.loc[:,'age_ratings']
game_modes = df.loc[:,'game_modes']
genres = df.loc[:,'genres']
themes = df.loc[:,'themes']
ids = df.loc[:,'id']

# %%
age_list = []
gm_list = []
genres_list = []
themes_list = []

for i in age_ratings:
    i = i.replace('[', "")
    i = i.replace(' ', "")
    i = i.replace(']', "").split(",")
    age_list.append(i)

for i in game_modes:
    i = i.replace('[', "")
    i = i.replace(' ', "")
    i = i.replace(']', "").split(",")
    gm_list.append(i)

for i in genres:
    i = i.replace('[', "")
    i = i.replace(' ', "")
    i = i.replace(']', "").split(",")
    genres_list.append(i)
    
for i in themes:
    i = i.replace('[', "")
    i = i.replace(' ', "")
    i = i.replace(']', "").split(",")
genre    themes_list.append(i)

# %%
genre_ids = []
genres_f = []
for c, genre in enumerate( genres_list ):
    for item in genre:
        genre_ids.append(ids[c])
        genres_f.append(item)
        
gm_ids = []
gm_f = []
for c, gm in enumerate( gm_list ):
    for item in gm:
        gm_ids.append(ids[c])
        gm_f.append(item)
        
theme_ids = []
theme_f = []
for c, theme in enumerate( themes_list ):
    for item in theme:
        theme_ids.append(ids[c])
        theme_f.append(item)
        
age_ids = []
age_f = []
for c, age in enumerate( age_list ):
    for item in age:
        age_ids.append(ids[c])
        age_f.append(item)

# %%
df1 = pd.DataFrame(list(zip(genre_ids, gm_f)), 
               columns =['game_id', 'genre']) 
df1.to_csv('genres.csv')

df = pd.DataFrame(list(zip(gm_ids, gm_f)), 
               columns =['game_id', 'game_mode']) 
df.to_csv('game_modes.csv')

df = pd.DataFrame(list(zip(theme_ids, theme_f)), 
               columns =['game_id', 'theme']) 
df.to_csv('themes.csv')

df = pd.DataFrame(list(zip(age_ids, age_f)), 
               columns =['game_id', 'age_rating']) 
df.to_csv('age_ratings.csv')

# %%
#VV----active Code----VV#
#Creating csv from 2 lists
df = pd.DataFrame(list(zip(unpacked_games, unpacked_urls)), 
               columns =['game_id', 'url']) 
df.set_index('game_id')
df.to_csv('artworks.csv')

# %%
#Response Test
response = requests.get(base_url,headers=header,params=params)
print(response)
df = pd.DataFrame(response.json())
df
# Out:
# <Response [200]>
#      created_at                                              games    id  \
# 0    1322611200                                                NaN    20
# 1    1359676800  [5, 6, 81, 82, 83, 84, 214, 216, 674, 753, 832...    43
# 2    1372550400                                             [2326]    61
# 3    1381708800  [341, 3011, 3149, 3150, 3941, 3942, 3943, 3944...   133
# 4    1390521600                                             [4099]   237
# 5    1317772800  [562, 874, 908, 909, 910, 911, 984, 1853, 2114...     9
# 6    1317772800  [293, 310, 633, 634, 635, 863, 864, 865, 866, ...    10
# 7    1318032000  [774, 1052, 2965, 2972, 2973, 3025, 3092, 3154...    11
# 8    1383782400                                       [3123, 4013]   139
# 9    1387756800                                             [3248]   144
# 10   1389225600                                             [3660]   158
# 11   1392076800                                       [5318, 7389]   357
# 12   1396310400                                             [5746]   374
# 13   1325980800                                                NaN    21
# 14   1364342400                                             [1987]    47
# 15   1375056000                                       [2818, 2819]   105
# 16   1375056000                                             [2821]   110
# 17   1389830400                                             [3763]   163
# 18   1390003200                           [2966, 3779, 3780, 6478]   166
# 19   1390176000                                             [3902]   199
# 20   1390608000                                       [4160, 4358]   243
# 21   1391990400                                      [5252, 19844]   348
# 22   1396310400                                             [5747]   375
# 23   1397952000                               [6216, 11290, 12970]   394
# 24   1428883200        [21842, 54217, 54218, 54220, 87504, 106988]   552
# 25   1445040000                                     [13658, 86426]   712
# 26   1446422400                                                NaN   730
# 27   1452211200                                            [15847]   751
# 28   1457222400                                            [18192]   775
# 29   1459728000                                      [3601, 41497]   791
# ..          ...                                                ...   ...
# 470  1488412800                              [18453, 18818, 27533]   971
# 471  1490918400                                     [28011, 28054]   989
# 472  1493683200                                            [20051]  1007
# 473  1390867200                                             [4597]   263
# 474  1390867200                               [4615, 18916, 25988]   265
# 475  1390867200                                [4619, 6538, 12593]   266
# 476  1391126400                                 [4669, 4670, 4671]   268
# 477  1391126400                                [4682, 6310, 36913]   271
# 478  1483315200                                                NaN   934
# 479  1496534400                                            [36728]  1024
# 480  1496534400                                            [22049]  1025
# 481  1502668800                                            [54652]  1074
# 482  1503360000                                             [6864]  1080
# 483  1483574400                                            [26693]   938
# 484  1484870400                                            [26851]   945
# 485  1487203200                                           [100023]   964
# 486  1491955200                                            [28123]   997
# 487  1504915200                    [19958, 103288, 105056, 107319]  1094
# 488  1513382400                       [64882, 64886, 64891, 64893]  1172
# 489  1514332800                                            [79132]  1193
# 490  1521504000                                            [87796]  1235
# 491  1537142400                                                NaN  1328
# 492  1542585600                                            [37016]  1344
# 493  1544140800                                                NaN  1349
# 494  1414886400                                       [8059, 8060]   481
# 495  1415577600                                  [250, 433, 20930]   491
# 496  1351987200  [1714, 1715, 1716, 1717, 1718, 1719, 1720, 172...    38
# 497  1355011200  [1831, 1871, 3015, 3097, 7631, 11670, 11744, 1...    39
# 498  1360454400                                             [1919]    45
# 499  1372118400                                 [1282, 1283, 1287]    52
#
#                             name                         slug  updated_at  \
# 0            Beneath a Steel Sky          beneath-a-steel-sky  1323216000
# 1             Dungeons & Dragons             dungeons-dragons  1359676800
# 2                      Spartacus                    spartacus  1372550400
# 3                   Harry Potter                 harry-potter  1381708800
# 4                          Shamu                        shamu  1390521600
# 5                     Tom Clancy                   tom-clancy  1323216000
# 6                      Sid Meier                    sid-meier  1323216000
# 7          The Lord of the Rings        the-lord-of-the-rings  1323216000
# 8            Mission: Impossible           mission-impossible  1383782400
# 9                   Johnny Bravo                 johnny-bravo  1387756800
# 10                       Othello                      othello  1389225600
# 11                Phineas & Ferb                 phineas-ferb  1392076800
# 12                     The Bible                    the-bible  1396310400
# 13                    BloodRayne                   bloodrayne  1325980800
# 14                          XIII                         xiii  1364342400
# 15           Hi Hi Puffy AmiYumi          hi-hi-puffy-amiyumi  1375056000
# 16          The Secret Saturdays         the-secret-saturdays  1375056000
# 17                   Pacific Rim                  pacific-rim  1389830400
# 18                 Jimmy Neutron                jimmy-neutron  1390003200
# 19                  Duel Masters                 duel-masters  1390176000
# 20                         Spawn                        spawn  1390608000
# 21                         I Spy                        i-spy  1391990400
# 22                       Bicycle                      bicycle  1396310400
# 23               Trivial Pursuit              trivial-pursuit  1397952000
# 24                       Persona                      persona  1428883200
# 25        Mikakunin de Shinkokei       mikakunin-de-shinkokei  1445040000
# 26                  Kane & Lynch               kane-and-lynch  1446422400
# 27                     Aeon Flux                    aeon-flux  1452211200
# 28                       Gradius                      gradius  1457222400
# 29                Space Invaders               space-invaders  1459728000
# ..                           ...                          ...         ...
# 470                  Source mods                  source-mods  1488412800
# 471                   Mas3dStudi                   mas3dstudi  1490918400
# 472  Sentinels of the Multiverse  sentinels-of-the-multiverse  1493683200
# 473               Caesars Palace               caesars-palace  1390867200
# 474                  The Goonies                  the-goonies  1390867200
# 475                       Popeye                       popeye  1390867200
# 476      Alvin and the Chipmunks      alvin-and-the-chipmunks  1391126400
# 477                    Astro Boy                    astro-boy  1391126400
# 478                  Don't Delet                   dont-delet  1483315200
# 479                   Asuka 120%            asuka-120-percent  1496534400
# 480               Capcom vs. SNK                capcom-vs-snk  1496534400
# 481            Eternity Warriors            eternity-warriors  1502668800
# 482                  dead rising                  dead-rising  1503360000
# 483                        SMITE                        smite  1483574400
# 484                   Mini Cleps                   mini-cleps  1484870400
# 485                       Q*bert                  q-star-bert  1487203200
# 486                      running                      running  1491955200
# 487              Hunter x Hunter              hunter-x-hunter  1504915200
# 488                    Gunparade                    gunparade  1513382400
# 489                       Adiboo                       adiboo  1514332800
# 490                Gurren Lagann                gurren-lagann  1521504000
# 491            Stones of Yalmrit            stones-of-yalmrit  1537142400
# 492                        Metro                        metro  1542585600
# 493                    spiderman                    spiderman  1544140800
# 494                  ThunderCats                  thundercats  1414886400
# 495    The Chronicles of Riddick    the-chronicles-of-riddick  1415577600
# 496                     Mega Man                     mega-man  1351987200
# 497             The Walking Dead             the-walking-dead  1355011200
# 498                     Deadpool                     deadpool  1360454400
# 499            Fables and Fiends            fables-and-fiends  1372118400
#
#                                                    url
# 0    https://www.igdb.com/franchises/beneath-a-stee...
# 1     https://www.igdb.com/franchises/dungeons-dragons
# 2            https://www.igdb.com/franchises/spartacus
# 3         https://www.igdb.com/franchises/harry-potter
# 4                https://www.igdb.com/franchises/shamu
# 5           https://www.igdb.com/franchises/tom-clancy
# 6            https://www.igdb.com/franchises/sid-meier
# 7    https://www.igdb.com/franchises/the-lord-of-th...
# 8    https://www.igdb.com/franchises/mission-imposs...
# 9         https://www.igdb.com/franchises/johnny-bravo
# 10             https://www.igdb.com/franchises/othello
# 11        https://www.igdb.com/franchises/phineas-ferb
# 12           https://www.igdb.com/franchises/the-bible
# 13          https://www.igdb.com/franchises/bloodrayne
# 14                https://www.igdb.com/franchises/xiii
# 15   https://www.igdb.com/franchises/hi-hi-puffy-am...
# 16   https://www.igdb.com/franchises/the-secret-sat...
# 17         https://www.igdb.com/franchises/pacific-rim
# 18       https://www.igdb.com/franchises/jimmy-neutron
# 19        https://www.igdb.com/franchises/duel-masters
# 20               https://www.igdb.com/franchises/spawn
# 21               https://www.igdb.com/franchises/i-spy
# 22             https://www.igdb.com/franchises/bicycle
# 23     https://www.igdb.com/franchises/trivial-pursuit
# 24             https://www.igdb.com/franchises/persona
# 25   https://www.igdb.com/franchises/mikakunin-de-s...
# 26      https://www.igdb.com/franchises/kane-and-lynch
# 27           https://www.igdb.com/franchises/aeon-flux
# 28             https://www.igdb.com/franchises/gradius
# 29      https://www.igdb.com/franchises/space-invaders
# ..                                                 ...
# 470        https://www.igdb.com/franchises/source-mods
# 471         https://www.igdb.com/franchises/mas3dstudi
# 472  https://www.igdb.com/franchises/sentinels-of-t...
# 473     https://www.igdb.com/franchises/caesars-palace
# 474        https://www.igdb.com/franchises/the-goonies
# 475             https://www.igdb.com/franchises/popeye
# 476  https://www.igdb.com/franchises/alvin-and-the-...
# 477          https://www.igdb.com/franchises/astro-boy
# 478         https://www.igdb.com/franchises/dont-delet
# 479  https://www.igdb.com/franchises/asuka-120-percent
# 480      https://www.igdb.com/franchises/capcom-vs-snk
# 481  https://www.igdb.com/franchises/eternity-warriors
# 482        https://www.igdb.com/franchises/dead-rising
# 483              https://www.igdb.com/franchises/smite
# 484         https://www.igdb.com/franchises/mini-cleps
# 485        https://www.igdb.com/franchises/q-star-bert
# 486            https://www.igdb.com/franchises/running
# 487    https://www.igdb.com/franchises/hunter-x-hunter
# 488          https://www.igdb.com/franchises/gunparade
# 489             https://www.igdb.com/franchises/adiboo
# 490      https://www.igdb.com/franchises/gurren-lagann
# 491  https://www.igdb.com/franchises/stones-of-yalmrit
# 492              https://www.igdb.com/franchises/metro
# 493          https://www.igdb.com/franchises/spiderman
# 494        https://www.igdb.com/franchises/thundercats
# 495  https://www.igdb.com/franchises/the-chronicles...
# 496           https://www.igdb.com/franchises/mega-man
# 497   https://www.igdb.com/franchises/the-walking-dead
# 498           https://www.igdb.com/franchises/deadpool
# 499  https://www.igdb.com/franchises/fables-and-fiends
#
# [500 rows x 7 columns]

# %%
#This is only necessary for cleaning if reading from csv. From Json ignore this step
art_set = set()

for i in artworks:
    i = i.replace('[', "")
    i = i.replace(' ', "")
    i = i.replace('0', "")
    i = i.replace(']', "").split(",")
    age_ratings_set.update(i)

art_set = list(new_set)

# %%
#This takes a lists out of dfs into new records. r = result
#Age ratings
lst_col = 'age_ratings'
r = pd.DataFrame({
      col:np.repeat(age_ratings[col].values, age_ratings[lst_col].str.len())
      for col in age_ratings.columns.drop(lst_col)}
    ).assign(**{lst_col:np.concatenate(age_ratings[lst_col].values)})[age_ratings.columns]

# %%
df_p = pd.read_csv('primary_ds.csv')

# %%
#Removing all newlines, all commas
clean_df = clean_df.replace(r'\\n',' ', regex=True) 
clean_df = clean_df.replace(r',',';', regex=True)

# %%
#VV----Inactive Code----VV#
# Creating new primary df, saving it
#df = df.set_index('id')
#df.to_csv("age_rating_codes_ds.csv")
tbo_df = df.loc[:,['age_ratings', 'artworks', 'dlcs', 'expansions', 'franchises', 'game_modes', 'genres',\
          'keywords', 'multiplayer_modes', 'release_dates', 'similar_games', 'tags', 'themes']]
df.to_csv("primary_ds_new.csv")

# %%
ratings =  df.loc[:, 'ratings']
ids = df.loc[:, 'ids']
descriptions = df2.loc[:, 'description']
desc_ids = df2.loc[:,'id']
new_descriptions = []

# %%
for c,  rating in enumerate( ratings ):
    for i,  id in enumerate( desc_ids ):
        if id == rating:
            new_descriptions.append(descriptions[i])

# %%
df = pd.DataFrame(list(zip(ids, new_descriptions)), 
               columns =['ids', 'descriptions']) 
df.to_csv('age_description_ds.csv')

# %%
age_ratings = tbo_df[['age_ratings', 'id']]
age_ratings = age_ratings.dropna()
age_ratings

# %%
df = df.drop(['age_ratings', 'artworks', 'dlcs', 'expansions', 'franchises', 'game_modes', 'genres',\
          'keywords', 'multiplayer_modes', 'release_dates', 'similar_games', 'tags', 'themes'], axis=1)

# %%
unpacked_games = []
for game in game_ids:
    for thing in game:
        unpacked_games.append(thing)
        
unpacked_urls = []
for game in art_urls:
    for thing in game:
        unpacked_urls.append(thing)

# %%
#Franchise 
franchise = df_p.loc[:,'franchise']

f_slug = []
ff_urls = []
ff_ids = []
for slug in slugs:
    for item in slug:
        f_slug.append(item)
for url in f_urls:
    for item in url:
        ff_urls.append(item)
for ids in f_ids:
    for item in ids:
        ff_ids.append(item)
        
frachise_dict = {'slugs' : f_slug, 'urls' : ff_urls, 'ids': ff_ids}
ff_df = pd.DataFrame(frachise_dict)

ff_df = ff_df.set_index('ids')

ff_df.to_csv('frachise_ds.csv')

# %%
#Keywords
keyword_set = set()

for i in keywords:
    i = i.replace('[', "")
    i = i.replace(' ', "")
    i = i.replace('0', "")
    i = i.replace(']', "").split(",")
    age_ratings_set.update(i)

keyword_set = list(keyword_set)

lst_col = 'keywords'
r = pd.DataFrame({
      col:np.repeat(df_p[col].values, df_p[lst_col].str.len())
      for col in df_p.columns.drop(lst_col)}
    ).assign(**{lst_col:np.concatenate(df_p[lst_col].values)})[df_p.columns]

keywords = df_p.loc[:,'keywords']
df = pd.DataFrame(list(zip(keywords, ids)), 
               columns =['game_id', 'url'])

# %%
#Similar Games
similar_games = df_p.loc[:,'similar_games']
ids = df_p.loc[:,'id']

similar_game = []
ids2 = []

for c, i in enumerate( similar_games ):
    i = i.replace('[', "")
    i = i.replace(' ', "")
    i = i.replace('0', "")
    i = i.replace('\'', "")
    i = i.replace(']', "").split(",")
    similar_game.append(i)
    ids2.append(ids[c])
    
similar_game2 = []
ids3 = []

for c, thing in enumerate( similar_game ):
    for item in thing:
        similar_game2.append(item)
        ids3.append(ids[c])
        
df = pd.DataFrame(list(zip(similar_game2, ids3)), 
               columns =['game_id', 'url']) 
df.to_csv('similar_games_ds.csv')
