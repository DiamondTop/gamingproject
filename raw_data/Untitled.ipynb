# %%
import pandas as pd

# %%
df = pd.read_csv('original_ds.csv')
df.head(50)
# Out:
#     Unnamed: 0     age_ratings  aggregated_rating  aggregated_rating_count  \
# 0            0         [25494]           0.000000                      0.0
# 1            1         [25488]           0.000000                      0.0
# 2            2         [25485]          77.000000                     14.0
# 3            3         [25457]          91.400000                     11.0
# 4            4  [25428, 25841]          81.846154                     18.0
# 5            5          [6032]           0.000000                      0.0
# 6            6         [24208]          75.000000                      1.0
# 7            7               0          81.625000                     11.0
# 8            8  [25528, 25529]          54.000000                      1.0
# 9            9               0           0.000000                      0.0
# 10          10         [24721]          92.777778                     12.0
# ...
